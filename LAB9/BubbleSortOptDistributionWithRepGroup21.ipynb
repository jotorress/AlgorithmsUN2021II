# %% [markdown]
# # Bubble sort optimized time complexity, and time complexity histograms for permutations of n elements  with repetions
#
# ## Best case - Increasingly sorted array
#
# $$t_b(n)=n-1=\Theta (n)$$
#
# ## Worst case - decreasingly sorted array ($$\frac{n^2-n}{2} \text{ comparisons} + \frac{n^2-n}{2} \ \text{swaps} $$)
# $$t_w(n)=n^{2}-n=\Theta (n^{2})$$
#
# ## Average case over unifrom permutations of n different elements
#
# $$t_a(n)\approx 0.72934022n^{2} - 1.2637766n + 0.85689742=\Theta (n^{2})$$

# %%
from itertools import product

n=3 
perm = product(range(1,n+1), repeat = n)

c=0
for i in perm:
    print(i)
    c+=1

print(c)
# Out:
# (1, 1, 1)
# (1, 1, 2)
# (1, 1, 3)
# (1, 2, 1)
# (1, 2, 2)
# (1, 2, 3)
# (1, 3, 1)
# (1, 3, 2)
# (1, 3, 3)
# (2, 1, 1)
# (2, 1, 2)
# (2, 1, 3)
# (2, 2, 1)
# (2, 2, 2)
# (2, 2, 3)
# (2, 3, 1)
# (2, 3, 2)
# (2, 3, 3)
# (3, 1, 1)
# (3, 1, 2)
# (3, 1, 3)
# (3, 2, 1)
# (3, 2, 2)
# (3, 2, 3)
# (3, 3, 1)
# (3, 3, 2)
# (3, 3, 3)
# 27

# %%
from itertools import product
import numpy as np 

def bubbleSortOptAllCounters(unsorted):

    # Algorithm optimized
    intComps = 0
    intSwaps = 0
    intSteps = 0
    intPasses = 0
    for i in range(len(unsorted) - 1):
        isSwapped = False
        intPasses += 1
        for j in range(0, n - i - 1):
          # Counting comparisons
            intComps += 1
            if unsorted[j] > unsorted[j + 1]:
                # Counting swaps
                intSwaps += 1
                unsorted[j], unsorted[j + 1] = unsorted[j + 1], unsorted[j]
                isSwapped = True
            # If there's no swap, then the array is sorted and passes to the next permutation
        if not isSwapped:
            break
    intSteps = intSwaps + intComps

    return intComps, intSwaps, intSteps, intPasses

# %%
def maxinversions(arr):
  maxinv = 0
  n = len(arr) 
  for i in range(n-1):
    inv = 0
    for j in range(i+1,n):
      if arr[j] < arr[i]:
        inv +=1
    if inv > maxinv:
      maxinv = inv
  return maxinv

# %%
from itertools import product
import matplotlib.pyplot as plt
import numpy as np 
import math

n = 3
perm = product(range(1,n+1), repeat = n)

comps = []
swaps = []
steps = []
passes = [] 
maxinvs = []

# Print the obtained permutations
for i in perm:
    i = list(i)
    maxinvs.append(maxinversions(i))
    intComps, intSwaps, intSteps, intPasses = bubbleSortOptAllCounters(i)
    comps.append(intComps)
    swaps.append(intSwaps)
    steps.append(intSteps)
    passes.append(intPasses)

print("n =",n)  
print("number of permutations n! =",math.factorial(n)) 
print()
   
b = np.array(range(min(maxinvs)-1,max(maxinvs)+2) ) +0.5
plt.hist(maxinvs,bins=b, color="cadetblue")
plt.title("Bubble Sort Maximum number of inversions")
plt.xlabel("Maximun number of inversions ")
plt.ylabel("Frequency")
plt.show()

print("Maximum number of inversions") 
print("Maximum number of inversions exper min =",min(maxinvs))
print("Maximum number of inversions formula min = 0")
print("Maximum number of inversions exper max =",max(maxinvs))
print("Maximum number of inversions formula max n-1 =",n-1)
print("Maximum number of inversions exper mean =",np.mean(maxinvs))
print("Maximum number of inversions formula mean  n- math.sqrt(math.pi*n/2)=",n- math.sqrt(math.pi*n/2))
print("Maximum number of inversions exper stdev =",np.std(maxinvs))
print()

b = np.array(range(min(comps)-1,max(comps)+2) ) +0.5
plt.hist(comps,bins=b, color="orchid")
plt.title("Bubble Sort Comparisons")
plt.xlabel("Comparisons ")
plt.ylabel("Frequency")
plt.show()

print("Comparisons") 
print("Comparisons formula (n-1)*n/2 =",(n-1)*n/2)
print("Comparisons exper min =",min(comps))
print("Comparisonsexper max =",max(comps))
print("Comparisons exper mean =",np.mean(comps))
print("Comparisons exper stdev =",np.std(comps))
print()

b = np.array(range(min(swaps)-1,max(swaps)+2) ) +0.5
plt.hist(swaps,bins=b,color="palegreen")
plt.title("Bubble Sort Swaps")
plt.xlabel("Swaps ")
plt.ylabel("Frequency")
plt.show()

print("Swaps") 
print("Swaps exper min =",min(swaps))
print("Swaps min formula = 0")
print("Swaps exper max =",max(swaps))
print("Swaps max formula (n-1)*n/2 =",(n-1)*n/2)
print("Swaps exper mean =",np.mean(swaps))
print("Swaps mean formula (1/4*n**2)- (1/2*n)+(1/4) =",(1/4*n**2)- (1/2*n)+(1/4))
print("Swaps exper stdev =",np.std(swaps))
print()

b = np.array(range(min(steps)-1,max(steps)+2) ) +0.5
plt.hist(steps,bins=b,color="gold")
plt.title("Bubble Sort Steps")
plt.xlabel("Steps ")
plt.ylabel("Frequency")
plt.show()

print("Steps") 
print("Steps exper min =",min(steps))
print("Steps min formula (n-1)*n/2 =",(n-1)*n/2)
print("Steps exper max =",max(steps))
print("Steps max formula (n-1)*n =",(n-1)*n)
print("Steps exper mean =",np.mean(steps))
print("Steps mean formula approximation (0.72934022*(n**2))+(-1.2637766*n) + 0.85689742 =",(0.72934022*(n**2))+(-1.2637766*n) + 0.85689742)
print("Steps exper stdev",np.std(steps))
print()

b = np.array(range(min(passes)-1,max(passes)+2) ) +0.5
plt.hist(passes,bins=b,color="mediumpurple")
plt.title("Bubble Sort Passes")
plt.xlabel("Passes")
plt.ylabel("Frequency")
plt.show()
    
print("Passes") 
print("Passes formula (n-1) =",(n-1))
print("Passes exper min =",min(passes))
print("Passes exper max =",max(passes))
print("Passes exper mean =",np.mean(passes))
print("Passes exper stdev",np.std(passes))
# Out:
# n = 3
# number of permutations n! = 6
# Maximum number of inversions
# Maximum number of inversions exper min = 0
# Maximum number of inversions formula min = 0
# Maximum number of inversions exper max = 2
# Maximum number of inversions formula max n-1 = 2
# Maximum number of inversions exper mean = 0.8148148148148148
# Maximum number of inversions formula mean  n- math.sqrt(math.pi*n/2)= 0.8291962363251972
# Maximum number of inversions exper stdev = 0.7219847662821455
# Comparisons
# Comparisons formula (n-1)*n/2 = 3.0
# Comparisons exper min = 2
# Comparisonsexper max = 3
# Comparisons exper mean = 2.6296296296296298
# Comparisons exper stdev = 0.4829038818668629
# Swaps
# Swaps exper min = 0
# Swaps min formula = 0
# Swaps exper max = 3
# Swaps max formula (n-1)*n/2 = 3.0
# Swaps exper mean = 1.0
# Swaps mean formula (1/4*n**2)- (1/2*n)+(1/4) = 1.0
# Swaps exper stdev = 0.90267093384844
# Steps
# Steps exper min = 2
# Steps min formula (n-1)*n/2 = 3.0
# Steps exper max = 6
# Steps max formula (n-1)*n = 6
# Steps exper mean = 3.6296296296296298
# Steps mean formula approximation (0.72934022*(n**2))+(-1.2637766*n) + 0.85689742 = 3.6296296000000003
# Steps exper stdev 1.3374422285383547
# Passes
# Passes formula (n-1) = 2
# Passes exper min = 1
# Passes exper max = 2
# Passes exper mean = 1.6296296296296295
# Passes exper stdev 0.48290388186686284

# %%
from itertools import product
import matplotlib.pyplot as plt
import numpy as np 
import math

n = 4
perm = product(range(1,n+1), repeat = n)

comps = []
swaps = []
steps = []
passes = [] 
maxinvs = []

# Print the obtained permutations
for i in perm:
    i = list(i)
    maxinvs.append(maxinversions(i))
    intComps, intSwaps, intSteps, intPasses = bubbleSortOptAllCounters(i)
    comps.append(intComps)
    swaps.append(intSwaps)
    steps.append(intSteps)
    passes.append(intPasses)

print("n =",n)  
print("number of permutations n! =",math.factorial(n)) 
print()
   
b = np.array(range(min(maxinvs)-1,max(maxinvs)+2) ) +0.5
plt.hist(maxinvs,bins=b, color="cadetblue")
plt.title("Bubble Sort Maximum number of inversions")
plt.xlabel("Maximun number of inversions ")
plt.ylabel("Frequency")
plt.show()

print("Maximum number of inversions") 
print("Maximum number of inversions exper min =",min(maxinvs))
print("Maximum number of inversions formula min = 0")
print("Maximum number of inversions exper max =",max(maxinvs))
print("Maximum number of inversions formula max n-1 =",n-1)
print("Maximum number of inversions exper mean =",np.mean(maxinvs))
print("Maximum number of inversions formula mean  n- math.sqrt(math.pi*n/2)=",n- math.sqrt(math.pi*n/2))
print("Maximum number of inversions exper stdev =",np.std(maxinvs))
print()

b = np.array(range(min(comps)-1,max(comps)+2) ) +0.5
plt.hist(comps,bins=b, color="orchid")
plt.title("Bubble Sort Comparisons")
plt.xlabel("Comparisons ")
plt.ylabel("Frequency")
plt.show()

print("Comparisons") 
print("Comparisons formula (n-1)*n/2 =",(n-1)*n/2)
print("Comparisons exper min =",min(comps))
print("Comparisonsexper max =",max(comps))
print("Comparisons exper mean =",np.mean(comps))
print("Comparisons exper stdev =",np.std(comps))
print()

b = np.array(range(min(swaps)-1,max(swaps)+2) ) +0.5
plt.hist(swaps,bins=b,color="palegreen")
plt.title("Bubble Sort Swaps")
plt.xlabel("Swaps ")
plt.ylabel("Frequency")
plt.show()

print("Swaps") 
print("Swaps exper min =",min(swaps))
print("Swaps min formula = 0")
print("Swaps exper max =",max(swaps))
print("Swaps max formula (n-1)*n/2 =",(n-1)*n/2)
print("Swaps exper mean =",np.mean(swaps))
print("Swaps mean formula (1/4*n**2)- (1/2*n)+(1/4) =",(1/4*n**2)- (1/2*n)+(1/4))
print("Swaps exper stdev =",np.std(swaps))
print()

b = np.array(range(min(steps)-1,max(steps)+2) ) +0.5
plt.hist(steps,bins=b,color="gold")
plt.title("Bubble Sort Steps")
plt.xlabel("Steps ")
plt.ylabel("Frequency")
plt.show()

print("Steps") 
print("Steps exper min =",min(steps))
print("Steps min formula (n-1)*n/2 =",(n-1)*n/2)
print("Steps exper max =",max(steps))
print("Steps max formula (n-1)*n =",(n-1)*n)
print("Steps exper mean =",np.mean(steps))
print("Steps mean formula approximation (0.72934022*(n**2))+(-1.2637766*n) + 0.85689742 =",(0.72934022*(n**2))+(-1.2637766*n) + 0.85689742)
print("Steps exper stdev",np.std(steps))
print()

b = np.array(range(min(passes)-1,max(passes)+2) ) +0.5
plt.hist(passes,bins=b,color="mediumpurple")
plt.title("Bubble Sort Passes")
plt.xlabel("Passes")
plt.ylabel("Frequency")
plt.show()
    
print("Passes") 
print("Passes formula (n-1) =",(n-1))
print("Passes exper min =",min(passes))
print("Passes exper max =",max(passes))
print("Passes exper mean =",np.mean(passes))
print("Passes exper stdev",np.std(passes))
# Out:
# n = 4
# number of permutations n! = 24
# Maximum number of inversions
# Maximum number of inversions exper min = 0
# Maximum number of inversions formula min = 0
# Maximum number of inversions exper max = 3
# Maximum number of inversions formula max n-1 = 3
# Maximum number of inversions exper mean = 1.49609375
# Maximum number of inversions formula mean  n- math.sqrt(math.pi*n/2)= 1.4933717253689998
# Maximum number of inversions exper stdev = 0.89703525081846
# Comparisons
# Comparisons formula (n-1)*n/2 = 6.0
# Comparisons exper min = 3
# Comparisonsexper max = 6
# Comparisons exper mean = 5.21875
# Comparisons exper stdev = 0.9955957701296244
# Swaps
# Swaps exper min = 0
# Swaps min formula = 0
# Swaps exper max = 6
# Swaps max formula (n-1)*n/2 = 6.0
# Swaps exper mean = 2.25
# Swaps mean formula (1/4*n**2)- (1/2*n)+(1/4) = 2.25
# Swaps exper stdev = 1.4252192813739224
# Steps
# Steps exper min = 3
# Steps min formula (n-1)*n/2 = 6.0
# Steps exper max = 12
# Steps max formula (n-1)*n = 12
# Steps exper mean = 7.46875
# Steps mean formula approximation (0.72934022*(n**2))+(-1.2637766*n) + 0.85689742 = 7.47123454
# Steps exper stdev 2.2995838618106537
# Passes
# Passes formula (n-1) = 3
# Passes exper min = 1
# Passes exper max = 3
# Passes exper mean = 2.35546875
# Passes exper stdev 0.7089063533171625

# %%
from itertools import product
import matplotlib.pyplot as plt
import numpy as np 
import math

n = 5
perm = product(range(1,n+1), repeat = n)

comps = []
swaps = []
steps = []
passes = [] 
maxinvs = []

# Print the obtained permutations
for i in perm:
    i = list(i)
    maxinvs.append(maxinversions(i))
    intComps, intSwaps, intSteps, intPasses = bubbleSortOptAllCounters(i)
    comps.append(intComps)
    swaps.append(intSwaps)
    steps.append(intSteps)
    passes.append(intPasses)

print("n =",n)  
print("number of permutations n! =",math.factorial(n)) 
print()
   
b = np.array(range(min(maxinvs)-1,max(maxinvs)+2) ) +0.5
plt.hist(maxinvs,bins=b, color="cadetblue")
plt.title("Bubble Sort Maximum number of inversions")
plt.xlabel("Maximun number of inversions ")
plt.ylabel("Frequency")
plt.show()

print("Maximum number of inversions") 
print("Maximum number of inversions exper min =",min(maxinvs))
print("Maximum number of inversions formula min = 0")
print("Maximum number of inversions exper max =",max(maxinvs))
print("Maximum number of inversions formula max n-1 =",n-1)
print("Maximum number of inversions exper mean =",np.mean(maxinvs))
print("Maximum number of inversions formula mean  n- math.sqrt(math.pi*n/2)=",n- math.sqrt(math.pi*n/2))
print("Maximum number of inversions exper stdev =",np.std(maxinvs))
print()

b = np.array(range(min(comps)-1,max(comps)+2) ) +0.5
plt.hist(comps,bins=b, color="orchid")
plt.title("Bubble Sort Comparisons")
plt.xlabel("Comparisons ")
plt.ylabel("Frequency")
plt.show()

print("Comparisons") 
print("Comparisons formula (n-1)*n/2 =",(n-1)*n/2)
print("Comparisons exper min =",min(comps))
print("Comparisonsexper max =",max(comps))
print("Comparisons exper mean =",np.mean(comps))
print("Comparisons exper stdev =",np.std(comps))
print()

b = np.array(range(min(swaps)-1,max(swaps)+2) ) +0.5
plt.hist(swaps,bins=b,color="palegreen")
plt.title("Bubble Sort Swaps")
plt.xlabel("Swaps ")
plt.ylabel("Frequency")
plt.show()

print("Swaps") 
print("Swaps exper min =",min(swaps))
print("Swaps min formula = 0")
print("Swaps exper max =",max(swaps))
print("Swaps max formula (n-1)*n/2 =",(n-1)*n/2)
print("Swaps exper mean =",np.mean(swaps))
print("Swaps mean formula (1/4*n**2)- (1/2*n)+(1/4) =",(1/4*n**2)- (1/2*n)+(1/4))
print("Swaps exper stdev =",np.std(swaps))
print()

b = np.array(range(min(steps)-1,max(steps)+2) ) +0.5
plt.hist(steps,bins=b,color="gold")
plt.title("Bubble Sort Steps")
plt.xlabel("Steps ")
plt.ylabel("Frequency")
plt.show()

print("Steps") 
print("Steps exper min =",min(steps))
print("Steps min formula (n-1)*n/2 =",(n-1)*n/2)
print("Steps exper max =",max(steps))
print("Steps max formula (n-1)*n =",(n-1)*n)
print("Steps exper mean =",np.mean(steps))
print("Steps mean formula approximation (0.72934022*(n**2))+(-1.2637766*n) + 0.85689742 =",(0.72934022*(n**2))+(-1.2637766*n) + 0.85689742)
print("Steps exper stdev",np.std(steps))
print()

b = np.array(range(min(passes)-1,max(passes)+2) ) +0.5
plt.hist(passes,bins=b,color="mediumpurple")
plt.title("Bubble Sort Passes")
plt.xlabel("Passes")
plt.ylabel("Frequency")
plt.show()
    
print("Passes") 
print("Passes formula (n-1) =",(n-1))
print("Passes exper min =",min(passes))
print("Passes exper max =",max(passes))
print("Passes exper mean =",np.mean(passes))
print("Passes exper stdev",np.std(passes))
# Out:
# n = 5
# number of permutations n! = 120
# Maximum number of inversions
# Maximum number of inversions exper min = 0
# Maximum number of inversions formula min = 0
# Maximum number of inversions exper max = 4
# Maximum number of inversions formula max n-1 = 4
# Maximum number of inversions exper mean = 2.21856
# Maximum number of inversions formula mean  n- math.sqrt(math.pi*n/2)= 2.1975043918010355
# Maximum number of inversions exper stdev = 1.031926124487601
# Comparisons
# Comparisons formula (n-1)*n/2 = 10.0
# Comparisons exper min = 4
# Comparisonsexper max = 10
# Comparisons exper mean = 8.77152
# Comparisons exper stdev = 1.485165610159352
# Swaps
# Swaps exper min = 0
# Swaps min formula = 0
# Swaps exper max = 10
# Swaps max formula (n-1)*n/2 = 10.0
# Swaps exper mean = 4.0
# Swaps mean formula (1/4*n**2)- (1/2*n)+(1/4) = 4.0
# Swaps exper stdev = 2.0
# Steps
# Steps exper min = 4
# Steps min formula (n-1)*n/2 = 10.0
# Steps exper max = 20
# Steps max formula (n-1)*n = 20
# Steps exper mean = 12.77152
# Steps mean formula (3/4*n**2)-n+(1/4) = 14.0
# Steps exper stdev 3.2691951440071607
# Passes
# Passes formula (n-1) = 4
# Passes exper min = 1
# Passes exper max = 4
# Passes exper mean = 3.10528
# Passes exper stdev 0.8727634969451918

# %%
from itertools import product
import matplotlib.pyplot as plt
import numpy as np 
import math

n = 7
perm = product(range(1,n+1), repeat = n)

comps = []
swaps = []
steps = []
passes = [] 
maxinvs = []

# Print the obtained permutations
for i in perm:
    i = list(i)
    maxinvs.append(maxinversions(i))
    intComps, intSwaps, intSteps, intPasses = bubbleSortOptAllCounters(i)
    comps.append(intComps)
    swaps.append(intSwaps)
    steps.append(intSteps)
    passes.append(intPasses)

print("n =",n)  
print("number of permutations n! =",math.factorial(n)) 
print()
   
b = np.array(range(min(maxinvs)-1,max(maxinvs)+2) ) +0.5
plt.hist(maxinvs,bins=b, color="cadetblue")
plt.title("Bubble Sort Maximum number of inversions")
plt.xlabel("Maximun number of inversions ")
plt.ylabel("Frequency")
plt.show()

print("Maximum number of inversions") 
print("Maximum number of inversions exper min =",min(maxinvs))
print("Maximum number of inversions formula min = 0")
print("Maximum number of inversions exper max =",max(maxinvs))
print("Maximum number of inversions formula max n-1 =",n-1)
print("Maximum number of inversions exper mean =",np.mean(maxinvs))
print("Maximum number of inversions formula mean  n- math.sqrt(math.pi*n/2)=",n- math.sqrt(math.pi*n/2))
print("Maximum number of inversions exper stdev =",np.std(maxinvs))
print()

b = np.array(range(min(comps)-1,max(comps)+2) ) +0.5
plt.hist(comps,bins=b, color="orchid")
plt.title("Bubble Sort Comparisons")
plt.xlabel("Comparisons ")
plt.ylabel("Frequency")
plt.show()

print("Comparisons") 
print("Comparisons formula (n-1)*n/2 =",(n-1)*n/2)
print("Comparisons exper min =",min(comps))
print("Comparisonsexper max =",max(comps))
print("Comparisons exper mean =",np.mean(comps))
print("Comparisons exper stdev =",np.std(comps))
print()

b = np.array(range(min(swaps)-1,max(swaps)+2) ) +0.5
plt.hist(swaps,bins=b,color="palegreen")
plt.title("Bubble Sort Swaps")
plt.xlabel("Swaps ")
plt.ylabel("Frequency")
plt.show()

print("Swaps") 
print("Swaps exper min =",min(swaps))
print("Swaps min formula = 0")
print("Swaps exper max =",max(swaps))
print("Swaps max formula (n-1)*n/2 =",(n-1)*n/2)
print("Swaps exper mean =",np.mean(swaps))
print("Swaps mean formula (1/4*n**2)- (1/2*n)+(1/4) =",(1/4*n**2)- (1/2*n)+(1/4))
print("Swaps exper stdev =",np.std(swaps))
print()

b = np.array(range(min(steps)-1,max(steps)+2) ) +0.5
plt.hist(steps,bins=b,color="gold")
plt.title("Bubble Sort Steps")
plt.xlabel("Steps ")
plt.ylabel("Frequency")
plt.show()

print("Steps") 
print("Steps exper min =",min(steps))
print("Steps min formula (n-1)*n/2 =",(n-1)*n/2)
print("Steps exper max =",max(steps))
print("Steps max formula (n-1)*n =",(n-1)*n)
print("Steps exper mean =",np.mean(steps))
print("Steps mean formula approximation (0.72934022*(n**2))+(-1.2637766*n) + 0.85689742 =",(0.72934022*(n**2))+(-1.2637766*n) + 0.85689742)
print("Steps exper stdev",np.std(steps))
print()

b = np.array(range(min(passes)-1,max(passes)+2) ) +0.5
plt.hist(passes,bins=b,color="mediumpurple")
plt.title("Bubble Sort Passes")
plt.xlabel("Passes")
plt.ylabel("Frequency")
plt.show()
    
print("Passes") 
print("Passes formula (n-1) =",(n-1))
print("Passes exper min =",min(passes))
print("Passes exper max =",max(passes))
print("Passes exper mean =",np.mean(passes))
print("Passes exper stdev",np.std(passes))
# Out:
# n = 7
# number of permutations n! = 5040
# Maximum number of inversions
# Maximum number of inversions exper min = 0
# Maximum number of inversions formula min = 0
# Maximum number of inversions exper max = 6
# Maximum number of inversions formula max n-1 = 6
# Maximum number of inversions exper mean = 3.7279632028928664
# Maximum number of inversions formula mean  n- math.sqrt(math.pi*n/2)= 3.684042478021729
# Maximum number of inversions exper stdev = 1.2702839359999143
# Comparisons
# Comparisons formula (n-1)*n/2 = 21.0
# Comparisons exper min = 6
# Comparisonsexper max = 21
# Comparisons exper mean = 18.74813215581943
# Comparisons exper stdev = 2.5376211591556523
# Swaps
# Swaps exper min = 0
# Swaps min formula = 0
# Swaps exper max = 21
# Swaps max formula (n-1)*n/2 = 21.0
# Swaps exper mean = 9.0
# Swaps mean formula (1/4*n**2)- (1/2*n)+(1/4) = 9.0
# Swaps exper stdev = 3.295017884191656
# Steps
# Steps exper min = 6
# Steps min formula (n-1)*n/2 = 21.0
# Steps exper max = 42
# Steps max formula (n-1)*n = 42
# Steps exper mean = 27.74813215581943
# Steps mean formula approximation (0.72934022*(n**2))+(-1.2637766*n) + 0.85689742 = 27.748132000000002
# Steps exper stdev 5.373187736730251
# Passes
# Passes formula (n-1) = 6
# Passes exper min = 1
# Passes exper max = 6
# Passes exper mean = 4.6463997629753395
# Passes exper stdev 1.1479990634418065

# %%
from itertools import product
import matplotlib.pyplot as plt
import numpy as np 
import math

n = 8
perm = product(range(1,n+1), repeat = n)

comps = []
swaps = []
steps = []
passes = [] 
maxinvs = []

# Print the obtained permutations
for i in perm:
    i = list(i)
    maxinvs.append(maxinversions(i))
    intComps, intSwaps, intSteps, intPasses = bubbleSortOptAllCounters(i)
    comps.append(intComps)
    swaps.append(intSwaps)
    steps.append(intSteps)
    passes.append(intPasses)

print("n =",n)  
print("number of permutations n! =",math.factorial(n)) 
print()
   
b = np.array(range(min(maxinvs)-1,max(maxinvs)+2) ) +0.5
plt.hist(maxinvs,bins=b, color="cadetblue")
plt.title("Bubble Sort Maximum number of inversions")
plt.xlabel("Maximun number of inversions ")
plt.ylabel("Frequency")
plt.show()

print("Maximum number of inversions") 
print("Maximum number of inversions exper min =",min(maxinvs))
print("Maximum number of inversions formula min = 0")
print("Maximum number of inversions exper max =",max(maxinvs))
print("Maximum number of inversions formula max n-1 =",n-1)
print("Maximum number of inversions exper mean =",np.mean(maxinvs))
print("Maximum number of inversions formula mean  n- math.sqrt(math.pi*n/2)=",n- math.sqrt(math.pi*n/2))
print("Maximum number of inversions exper stdev =",np.std(maxinvs))
print()

b = np.array(range(min(comps)-1,max(comps)+2) ) +0.5
plt.hist(comps,bins=b, color="orchid")
plt.title("Bubble Sort Comparisons")
plt.xlabel("Comparisons ")
plt.ylabel("Frequency")
plt.show()

print("Comparisons") 
print("Comparisons formula (n-1)*n/2 =",(n-1)*n/2)
print("Comparisons exper min =",min(comps))
print("Comparisonsexper max =",max(comps))
print("Comparisons exper mean =",np.mean(comps))
print("Comparisons exper stdev =",np.std(comps))
print()

b = np.array(range(min(swaps)-1,max(swaps)+2) ) +0.5
plt.hist(swaps,bins=b,color="palegreen")
plt.title("Bubble Sort Swaps")
plt.xlabel("Swaps ")
plt.ylabel("Frequency")
plt.show()

print("Swaps") 
print("Swaps exper min =",min(swaps))
print("Swaps min formula = 0")
print("Swaps exper max =",max(swaps))
print("Swaps max formula (n-1)*n/2 =",(n-1)*n/2)
print("Swaps exper mean =",np.mean(swaps))
print("Swaps mean formula (1/4*n**2)- (1/2*n)+(1/4) =",(1/4*n**2)- (1/2*n)+(1/4))
print("Swaps exper stdev =",np.std(swaps))
print()

b = np.array(range(min(steps)-1,max(steps)+2) ) +0.5
plt.hist(steps,bins=b,color="gold")
plt.title("Bubble Sort Steps")
plt.xlabel("Steps ")
plt.ylabel("Frequency")
plt.show()

print("Steps") 
print("Steps exper min =",min(steps))
print("Steps min formula (n-1)*n/2 =",(n-1)*n/2)
print("Steps exper max =",max(steps))
print("Steps max formula (n-1)*n =",(n-1)*n)
print("Steps exper mean =",np.mean(steps))
print("Steps mean formula approximation (0.72934022*(n**2))+(-1.2637766*n) + 0.85689742 =",(0.72934022*(n**2))+(-1.2637766*n) + 0.85689742)
print("Steps exper stdev",np.std(steps))
print()

b = np.array(range(min(passes)-1,max(passes)+2) ) +0.5
plt.hist(passes,bins=b,color="mediumpurple")
plt.title("Bubble Sort Passes")
plt.xlabel("Passes")
plt.ylabel("Frequency")
plt.show()
    
print("Passes") 
print("Passes formula (n-1) =",(n-1))
print("Passes exper min =",min(passes))
print("Passes exper max =",max(passes))
print("Passes exper mean =",np.mean(passes))
print("Passes exper stdev",np.std(passes))
# Out:
# n = 8
# number of permutations n! = 40320
# Maximum number of inversions
# Maximum number of inversions exper min = 0
# Maximum number of inversions formula min = 0
# Maximum number of inversions exper max = 7
# Maximum number of inversions formula max n-1 = 7
# Maximum number of inversions exper mean = 4.506802499294281
# Maximum number of inversions formula mean  n- math.sqrt(math.pi*n/2)= 4.455092298188968
# Maximum number of inversions exper stdev = 1.3795120518929025
# Comparisons
# Comparisons formula (n-1)*n/2 = 28.0
# Comparisons exper min = 7
# Comparisonsexper max = 28
# Comparisons exper mean = 25.187055110931396
# Comparisons exper stdev = 3.1098130811715317
# Swaps
# Swaps exper min = 0
# Swaps min formula = 0
# Swaps exper max = 28
# Swaps max formula (n-1)*n/2 = 28.0
# Swaps exper mean = 12.25
# Swaps mean formula (1/4*n**2)- (1/2*n)+(1/4) = 12.25
# Swaps exper stdev = 4.00975373308636
# Steps
# Steps exper min = 7
# Steps min formula (n-1)*n/2 = 28.0
# Steps exper max = 56
# Steps max formula (n-1)*n = 56
# Steps exper mean = 37.4370551109314
# Steps mean formula approximation (0.72934022*(n**2))+(-1.2637766*n) + 0.85689742 = 37.4244587
# Steps exper stdev 6.511226704934139
# Passes
# Passes formula (n-1) = 7
# Passes exper min = 1
# Passes exper max = 7
# Passes exper mean = 5.4352588057518005
# Passes exper stdev 1.2699344781963453

# %%
# https://www.geeksforgeeks.org/bubble-sort/ no optimized adding only a steps counter, also fixing "for i in range(n-1):"

def bubbleSortOptSteps(unsorted):

    intComps = 0
    intSwaps = 0
    intSteps = 0
    intPasses = 0
    for i in range(len(unsorted) - 1):
        isSwapped = False
        intPasses += 1
        for j in range(0, n - i - 1):
          # Counting comparisons
            intComps += 1
            if unsorted[j] > unsorted[j + 1]:
                # Counting swaps
                intSwaps += 1
                unsorted[j], unsorted[j + 1] = unsorted[j + 1], unsorted[j]
                isSwapped = True
            # If there's no swap, then the array is sorted and passes to the next permutation
        if not isSwapped:
            break
    intSteps = intSwaps + intComps

    return intSteps

# %%
from itertools import product
import matplotlib.pyplot as plt
import numpy as np 

n = 3
perm = product(range(1,n+1), repeat = n)

times =  [] 
# Print the obtained permutations
for i in perm:
    i = list(i)
    times.append(bubbleSortOptSteps(i))

b = np.array(range(min(steps)-1,max(steps)+2) ) +0.5
plt.hist(steps,bins=b,color="hotpink")
plt.title("Bubble Sort Steps")
plt.xlabel("Steps ")
plt.ylabel("Frequency")
plt.show()

print("Steps") 
print("Steps exper min =",min(steps))
print("Steps min formula (n-1)*n/2 =",(n-1)*n/2)
print("Steps exper max =",max(steps))
print("Steps max formula (n-1)*n =",(n-1)*n)
print("Steps exper mean =",np.mean(steps))
print("Steps mean formula approximation (0.72934022*(n**2))+(-1.2637766*n) + 0.85689742 =",(0.72934022*(n**2))+(-1.2637766*n) + 0.85689742)
print("Steps exper stdev",np.std(steps))
print()
# Out:
# Steps
# Steps exper min = 7
# Steps min formula (n-1)*n/2 = 3.0
# Steps exper max = 56
# Steps max formula (n-1)*n = 6
# Steps exper mean = 37.4370551109314
# Steps mean formula (3/4*n**2)-n+(1/4) = 4.0
# Steps exper stdev 6.511226704934139

# %%
from itertools import product
import matplotlib.pyplot as plt
import numpy as np 

n = 5
perm = product(range(1,n+1), repeat = n)

times =  [] 
# Print the obtained permutations
for i in perm:
    i = list(i)
    times.append(bubbleSortOptSteps(i))

b = np.array(range(min(steps)-1,max(steps)+2) ) +0.5
plt.hist(steps,bins=b,color="yellowgreen")
plt.title("Bubble Sort Steps")
plt.xlabel("Steps ")
plt.ylabel("Frequency")
plt.show()

print("Steps") 
print("Steps exper min =",min(steps))
print("Steps min formula (n-1)*n/2 =",(n-1)*n/2)
print("Steps exper max =",max(steps))
print("Steps max formula (n-1)*n =",(n-1)*n)
print("Steps exper mean =",np.mean(steps))
print("Steps mean formula approximation (0.72934022*(n**2))+(-1.2637766*n) + 0.85689742 =",(0.72934022*(n**2))+(-1.2637766*n) + 0.85689742)
print("Steps exper stdev",np.std(steps))
print()
# Out:
# Steps
# Steps exper min = 7
# Steps min formula (n-1)*n/2 = 10.0
# Steps exper max = 56
# Steps max formula (n-1)*n = 20
# Steps exper mean = 37.4370551109314
# Steps mean formula (3/4*n**2)-n+(1/4) = 14.0
# Steps exper stdev 6.511226704934139

# %%
from itertools import product
import matplotlib.pyplot as plt
import numpy as np 

n = 8
perm = product(range(1,n+1), repeat = n)

times =  [] 
# Print the obtained permutations
for i in list(perm):
    i = list(i)
    times.append(bubbleSortOptSteps(i))

b = np.array(range(min(steps)-1,max(steps)+2) ) +0.5
plt.hist(steps,bins=b,color="yellowgreen")
plt.title("Bubble Sort Steps")
plt.xlabel("Steps ")
plt.ylabel("Frequency")
plt.show()

print("Steps") 
print("Steps exper min =",min(steps))
print("Steps min formula (n-1)*n/2 =",(n-1)*n/2)
print("Steps exper max =",max(steps))
print("Steps max formula (n-1)*n =",(n-1)*n)
print("Steps exper mean =",np.mean(steps))
print("Steps mean formula approximation (0.72934022*(n**2))+(-1.2637766*n) + 0.85689742 =",(0.72934022*(n**2))+(-1.2637766*n) + 0.85689742)
print("Steps exper stdev",np.std(steps))
print()
# Out:
# Steps
# Steps exper min = 7
# Steps min formula (n-1)*n/2 = 28.0
# Steps exper max = 56
# Steps max formula (n-1)*n = 56
# Steps exper mean = 37.4370551109314
# Steps mean formula (3/4*n**2)-n+(1/4) = 40.25
# Steps exper stdev 6.511226704934139

# %%
from itertools import product
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import random 

fig = plt.figure()
ax = plt.axes(projection="3d")

N = 8

x = []
y = []
z = []
dx = []
dy = []
dz = []

for n in np.arange(3,N+1,1):
   A = range(n)
   times = []

   for P in  product(A, repeat = n):
       t = bubbleSortOptSteps(list(P)) 
       times.append(t)  
 
   b = np.array(range(min(times)-1, max(times)+1))+0.5
   H = np.array(np.histogram(times,b))
   H[0] = H[0]/np.sum(H[0])
   for i in range(len(H[0])):
     x.append(n)
     y.append(H[1][i])
     z.append(0)
     dx.append(0.1)
     dy.append(0.1)
     dz.append(H[0][i])

ax.bar3d(x, y, z, dx, dy, dz, color='mediumpurple', zsort='average')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
from itertools import product
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import random 

fig = plt.figure()
ax = plt.axes(projection="3d")

N = 8

x = []
y = []
z = []
dx = []
dy = []
dz = []

for n in np.arange(3,N+1,1):
   A = range(n)
   times = []

   for P in  product(A, repeat = n):
       t = bubbleSortOptSteps(list(P)) 
       times.append(t)  
 
   b = np.array(range(min(times)-1, max(times)+1))+0.5
   H = np.array(np.histogram(times,b))
   H[0] = H[0]/np.sum(H[0])
   for i in range(len(H[0])):
     x.append(n)
     y.append(H[1][i])
     z.append(0)
     dx.append(0.1)
     dy.append(0.1)
     dz.append(H[0][i])

ax.view_init(30, 15)
ax.bar3d(x, y, z, dx, dy, dz, color='mediumpurple', zsort='average')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
import matplotlib.pyplot as plt
import numpy as np

n = np.arange(1,21,1)
plt.plot(n, (n-1)*n,  label = 'Bubble sort worst time $(n-1)*n$', color='sienna')
plt.plot(n, (0.72934022*(n**2))+(-1.2637766*n) + 0.85689742, label = 'Bubble sort average time $(0.72934022*(n**2))+(-1.2637766*n) + 0.85689742$', color='chocolate')
plt.plot(n, (n-1)*n/2, label = 'Bubble sort best time $(n-1)*n/2$',color='coral')
plt.xlabel('Array size')
plt.ylabel('Steps')
plt.legend(loc = 'upper left')

# %% [markdown]
# # Average case - expected number of comparisons + swaps on random unifrom permtation of n   elements with repetitions
#
# $$t_a(n)\approx 0.72934022n^{2} - 1.2637766n + 0.85689742=\Theta (n^{2})$$

# %%
# Average case on random unifrom permutation of $n$ elements with repetitions $t_a(n) = \frac{3}{4}n^2 - n +\frac{1}{4}= \Theta(n^2) $
import numpy as np 
import pandas as pd
import scipy.linalg as la

n = np.array([3.0,5.0,7.0])    # Number n of sorted elments 
t = np.array([3.6296296296296298 ,12.77152,27.74813215581943]) # Average comparisons + swaps for the corresponding n 

data = pd.DataFrame({'n': n, 't': t})
data
# Out:
#      n          t
# 0  3.0   3.629630
# 1  5.0  12.771520
# 2  7.0  27.748132

# %%
# Interpolating a polynomial of degree 3

X = np.column_stack([n**0,n**1,n**2])
a = la.solve(X,t)
a
# Out:
# array([ 0.85689742, -1.2637766 ,  0.72934022])

# %%
# Para un n = 8
(0.72934022*(8**2))+(-1.2637766*8) + 0.85689742
# Out:
# 37.4244587
